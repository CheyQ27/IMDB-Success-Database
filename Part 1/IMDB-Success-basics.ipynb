# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
import pandas as pd
import numpy as np

# %%
basics = pd.read_csv(basics_url,sep='\t', low_memory=False)

# %%
basics = basics.dropna(subset=['runtimeMinutes', 'genres'])

# %%
basics = basics[basics['titleType']=='movie']

# %%
basics = basics[(basics['startYear'] > "1999") & (basics['startYear'] < "2022")]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 11636  tt0011801     movie                                   Tötet nicht mehr
# 15174  tt0015414     movie                             La tierra de los toros
# 34790  tt0035423     movie                                     Kate & Leopold
# 61086  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67631  tt0069049     movie                         The Other Side of the Wind
#
#                                    originalTitle isAdult startYear endYear  \
# 11636                           Tötet nicht mehr       0      2019      \N
# 15174                     La tierra de los toros       0      2000      \N
# 34790                             Kate & Leopold       0      2001      \N
# 61086  El Tango del Viudo y Su Espejo Deformante       0      2020      \N
# 67631                 The Other Side of the Wind       0      2018      \N
#
#       runtimeMinutes                  genres
# 11636             \N            Action,Crime
# 15174             60                      \N
# 34790            118  Comedy,Fantasy,Romance
# 61086             70                   Drama
# 67631            122                   Drama

# %%
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0011801     movie                                   Tötet nicht mehr
# 1  tt0015414     movie                             La tierra de los toros
# 2  tt0035423     movie                                     Kate & Leopold
# 3  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 4  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear endYear  \
# 0                           Tötet nicht mehr        0       2019      \N
# 1                     La tierra de los toros        0       2000      \N
# 2                             Kate & Leopold        0       2001      \N
# 3  El Tango del Viudo y Su Espejo Deformante        0       2020      \N
# 4                 The Other Side of the Wind        0       2018      \N
#
#   runtimeMinutes                  genres
# 0             \N            Action,Crime
# 1             60                      \N
# 2            118  Comedy,Fantasy,Romance
# 3             70                   Drama
# 4            122                   Drama
